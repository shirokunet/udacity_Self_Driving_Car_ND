# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    x -= ( learning_rate * gradx)
    # Return the new value for x
    return x

# %%
import random


def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number between 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 50168894.000, x = 14166.000
# EPOCH 1: Cost = 32108093.960, x = 11332.800
# EPOCH 2: Cost = 20549181.934, x = 9066.240
# EPOCH 3: Cost = 13151478.238, x = 7252.992
# EPOCH 4: Cost = 8416947.872, x = 5802.394
# EPOCH 5: Cost = 5386848.438, x = 4641.915
# EPOCH 6: Cost = 3447584.801, x = 3713.532
# EPOCH 7: Cost = 2206456.072, x = 2970.826
# EPOCH 8: Cost = 1412133.686, x = 2376.660
# EPOCH 9: Cost = 903767.359, x = 1901.328
# EPOCH 10: Cost = 578412.910, x = 1521.063
# EPOCH 11: Cost = 370186.062, x = 1216.850
# EPOCH 12: Cost = 236920.880, x = 973.480
# EPOCH 13: Cost = 151631.163, x = 778.784
# EPOCH 14: Cost = 97045.744, x = 623.027
# EPOCH 15: Cost = 62111.076, x = 498.422
# EPOCH 16: Cost = 39752.889, x = 398.737
# EPOCH 17: Cost = 25443.649, x = 318.990
# EPOCH 18: Cost = 16285.735, x = 255.192
# EPOCH 19: Cost = 10424.671, x = 204.154
# EPOCH 20: Cost = 6673.589, x = 163.323
# EPOCH 21: Cost = 4272.897, x = 130.658
# EPOCH 22: Cost = 2736.454, x = 104.527
# EPOCH 23: Cost = 1753.131, x = 83.621
# EPOCH 24: Cost = 1123.804, x = 66.897
# EPOCH 25: Cost = 721.034, x = 53.518
# EPOCH 26: Cost = 463.262, x = 42.814
# EPOCH 27: Cost = 298.288, x = 34.251
# EPOCH 28: Cost = 192.704, x = 27.401
# EPOCH 29: Cost = 125.131, x = 21.921
# EPOCH 30: Cost = 81.884, x = 17.537
# EPOCH 31: Cost = 54.206, x = 14.029
# EPOCH 32: Cost = 36.492, x = 11.223
# EPOCH 33: Cost = 25.155, x = 8.979
# EPOCH 34: Cost = 17.899, x = 7.183
# EPOCH 35: Cost = 13.255, x = 5.746
# EPOCH 36: Cost = 10.283, x = 4.597
# EPOCH 37: Cost = 8.381, x = 3.678
# EPOCH 38: Cost = 7.164, x = 2.942
# EPOCH 39: Cost = 6.385, x = 2.354
# EPOCH 40: Cost = 5.886, x = 1.883
# EPOCH 41: Cost = 5.567, x = 1.506
# EPOCH 42: Cost = 5.363, x = 1.205
# EPOCH 43: Cost = 5.232, x = 0.964
# EPOCH 44: Cost = 5.149, x = 0.771
# EPOCH 45: Cost = 5.095, x = 0.617
# EPOCH 46: Cost = 5.061, x = 0.494
# EPOCH 47: Cost = 5.039, x = 0.395
# EPOCH 48: Cost = 5.025, x = 0.316
# EPOCH 49: Cost = 5.016, x = 0.253
# EPOCH 50: Cost = 5.010, x = 0.202
# EPOCH 51: Cost = 5.007, x = 0.162
# EPOCH 52: Cost = 5.004, x = 0.129
# EPOCH 53: Cost = 5.003, x = 0.104
# EPOCH 54: Cost = 5.002, x = 0.083
# EPOCH 55: Cost = 5.001, x = 0.066
# EPOCH 56: Cost = 5.001, x = 0.053
# EPOCH 57: Cost = 5.000, x = 0.042
# EPOCH 58: Cost = 5.000, x = 0.034
# EPOCH 59: Cost = 5.000, x = 0.027
# EPOCH 60: Cost = 5.000, x = 0.022
# EPOCH 61: Cost = 5.000, x = 0.017
# EPOCH 62: Cost = 5.000, x = 0.014
# EPOCH 63: Cost = 5.000, x = 0.011
# EPOCH 64: Cost = 5.000, x = 0.009
# EPOCH 65: Cost = 5.000, x = 0.007
# EPOCH 66: Cost = 5.000, x = 0.006
# EPOCH 67: Cost = 5.000, x = 0.005
# EPOCH 68: Cost = 5.000, x = 0.004
# EPOCH 69: Cost = 5.000, x = 0.003
# EPOCH 70: Cost = 5.000, x = 0.002
# EPOCH 71: Cost = 5.000, x = 0.002
# EPOCH 72: Cost = 5.000, x = 0.001
# EPOCH 73: Cost = 5.000, x = 0.001
# EPOCH 74: Cost = 5.000, x = 0.001
# EPOCH 75: Cost = 5.000, x = 0.001
# EPOCH 76: Cost = 5.000, x = 0.001
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000
